# %%
from mch.models.training import BatchModelTrainer
from mch.config.modelTrainingParameters import resultsDirectory, parameter_grid
# Out:
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# /data/projects/classifiers/methylation/src/mch/config/settings.py:25: DtypeWarning: Columns (4854) have mixed types. Specify dtype option on import or set low_memory=False.
#   mvalue_df = pd.read_csv(mvalue_path)

# %%
models = BatchModelTrainer()
models.train_all_models()
# Out:
# INFO:root:Training model for node: Solid tumour
# Solid tumour (177, 4855) (177, 2)
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# 1273                  Carcinoma
# 1092        Liver tumour, Solid
# 1296       Kidney tumour, Solid
# 301                   Carcinoma
# 625         Liver tumour, Solid
#                  ...
# 149                 Solid other
# 491         Liver tumour, Solid
# 808              Thyroid tumour
# 112                 Solid other
# 716     Adrenal cortical tumour
# Name: cancerType, Length: 94, dtype: object
# probe identification for: Carcinoma, 1 of 10 cancer types
# running analysis
# ['Carcinoma' 'otherCancerType']
# 1273                    Carcinoma
# 1092          Liver tumour, Solid
# 753       Adrenal cortical tumour
# 1296         Kidney tumour, Solid
# 301                     Carcinoma
#                   ...
# 961                   Solid other
# 1723          Liver tumour, Solid
# 112                   Solid other
# 716       Adrenal cortical tumour
# 790     Melanocytic tumour, Solid
# Name: cancerType, Length: 94, dtype: object
# probe identification for: Carcinoma, 1 of 10 cancer types
# running analysis
# ['Carcinoma' 'otherCancerType']
# 1273                  Carcinoma
# 1092        Liver tumour, Solid
# 1296       Kidney tumour, Solid
# 301                   Carcinoma
# 625         Liver tumour, Solid
#                  ...
# 149                 Solid other
# 491         Liver tumour, Solid
# 808              Thyroid tumour
# 112                 Solid other
# 716     Adrenal cortical tumour
# Name: cancerType, Length: 94, dtype: object
# probe identification for: Carcinoma, 1 of 10 cancer types
# running analysis
# ['Carcinoma' 'otherCancerType']
# 1273                    Carcinoma
# 1092          Liver tumour, Solid
# 753       Adrenal cortical tumour
# 1296         Kidney tumour, Solid
# 301                     Carcinoma
#                   ...
# 961                   Solid other
# 1723          Liver tumour, Solid
# 112                   Solid other
# 716       Adrenal cortical tumour
# 790     Melanocytic tumour, Solid
# Name: cancerType, Length: 94, dtype: object
# probe identification for: Carcinoma, 1 of 10 cancer types
# running analysis
# ['Carcinoma' 'otherCancerType']
# 753       Adrenal cortical tumour
# 859     Melanocytic tumour, Solid
# 474                     Carcinoma
# 1182         Kidney tumour, Solid
# 25                    Solid other
#                   ...
# 1723          Liver tumour, Solid
# 149                   Solid other
# 491           Liver tumour, Solid
# 808                Thyroid tumour
# 790     Melanocytic tumour, Solid
# Name: cancerType, Length: 94, dtype: object
# probe identification for: Adrenal cortical tumour, 1 of 10 cancer types
# running analysis
# ['Adrenal cortical tumour' 'otherCancerType']
# 753       Adrenal cortical tumour
# 859     Melanocytic tumour, Solid
# 474                     Carcinoma
# 1182         Kidney tumour, Solid
# 25                    Solid other
#                   ...
# 1723          Liver tumour, Solid
# 149                   Solid other
# 491           Liver tumour, Solid
# 808                Thyroid tumour
# 790     Melanocytic tumour, Solid
# Name: cancerType, Length: 94, dtype: object
# probe identification for: Adrenal cortical tumour, 1 of 10 cancer types
# running analysis
# ['Adrenal cortical tumour' 'otherCancerType']
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
# Shape of data internal to the differential analysis (94, 4853)
# Shape of data internal to the differential analysis (94, 4045)
# 1273                    Carcinoma
# 1092          Liver tumour, Solid
# 753       Adrenal cortical tumour
# 1296         Kidney tumour, Solid
# 301                     Carcinoma
#                   ...
# 961                   Solid other
# 1723          Liver tumour, Solid
# 112                   Solid other
# 716       Adrenal cortical tumour
# 790     Melanocytic tumour, Solid
# Name: cancerType, Length: 94, dtype: object
# probe identification for: Carcinoma, 1 of 10 cancer types
# running analysis
# ['Carcinoma' 'otherCancerType']
# 753       Adrenal cortical tumour
# 859     Melanocytic tumour, Solid
# 474                     Carcinoma
# 1182         Kidney tumour, Solid
# 25                    Solid other
#                   ...
# 1723          Liver tumour, Solid
# 149                   Solid other
# 491           Liver tumour, Solid
# 808                Thyroid tumour
# 790     Melanocytic tumour, Solid
# Name: cancerType, Length: 94, dtype: object
# probe identification for: Adrenal cortical tumour, 1 of 10 cancer types
# running analysis
# ['Adrenal cortical tumour' 'otherCancerType']
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R home found: /usr/lib/R
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# ERROR:root:Error training model for Solid tumour: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# INFO:root:Training model for node: Sarcoma
# Sarcoma (367, 4855) (367, 2)
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# 1311    Bone tumour, Sarcoma
# 313            Ewing sarcoma
# 1357    Bone tumour, Sarcoma
# 90             Sarcoma other
# 1075    Bone tumour, Sarcoma
#                 ...
# 749            Sarcoma other
# 265            Sarcoma other
# 424         Rhabdomyosarcoma
# 1067           Ewing sarcoma
# 1332           Ewing sarcoma
# Name: cancerType, Length: 196, dtype: object
# probe identification for: Bone tumour, Sarcoma, 1 of 7 cancer types
# running analysis
# ['Bone tumour, Sarcoma' 'otherCancerType']
# 819                               Sarcoma other
# 282                               Sarcoma other
# 313                               Ewing sarcoma
# 256     Peripheral nerve sheath tumour, Sarcoma
# 1075                       Bone tumour, Sarcoma
#                          ...
# 101                            Rhabdomyosarcoma
# 265                               Sarcoma other
# 1067                              Ewing sarcoma
# 1332                              Ewing sarcoma
# 383                               Sarcoma other
# Name: cancerType, Length: 195, dtype: object
# probe identification for: Sarcoma other, 1 of 7 cancer types
# running analysis
# ['Sarcoma other' 'otherCancerType']
# 1311    Bone tumour, Sarcoma
# 819            Sarcoma other
# 282            Sarcoma other
# 1357    Bone tumour, Sarcoma
# 90             Sarcoma other
#                 ...
# 478     Bone tumour, Sarcoma
# 101         Rhabdomyosarcoma
# 749            Sarcoma other
# 424         Rhabdomyosarcoma
# 383            Sarcoma other
# Name: cancerType, Length: 195, dtype: object
# probe identification for: Bone tumour, Sarcoma, 1 of 7 cancer types
# running analysis
# ['Bone tumour, Sarcoma' 'otherCancerType']
# 1311    Bone tumour, Sarcoma
# 819            Sarcoma other
# 282            Sarcoma other
# 1357    Bone tumour, Sarcoma
# 90             Sarcoma other
#                 ...
# 478     Bone tumour, Sarcoma
# 101         Rhabdomyosarcoma
# 749            Sarcoma other
# 424         Rhabdomyosarcoma
# 383            Sarcoma other
# Name: cancerType, Length: 195, dtype: object
# probe identification for: Bone tumour, Sarcoma, 1 of 7 cancer types
# running analysis
# ['Bone tumour, Sarcoma' 'otherCancerType']
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# 1311    Bone tumour, Sarcoma
# 313            Ewing sarcoma
# 1357    Bone tumour, Sarcoma
# 90             Sarcoma other
# 1075    Bone tumour, Sarcoma
#                 ...
# 749            Sarcoma other
# 265            Sarcoma other
# 424         Rhabdomyosarcoma
# 1067           Ewing sarcoma
# 1332           Ewing sarcoma
# Name: cancerType, Length: 196, dtype: object
# probe identification for: Bone tumour, Sarcoma, 1 of 7 cancer types
# running analysis
# ['Bone tumour, Sarcoma' 'otherCancerType']
# 819                               Sarcoma other
# 282                               Sarcoma other
# 313                               Ewing sarcoma
# 256     Peripheral nerve sheath tumour, Sarcoma
# 1075                       Bone tumour, Sarcoma
#                          ...
# 101                            Rhabdomyosarcoma
# 265                               Sarcoma other
# 1067                              Ewing sarcoma
# 1332                              Ewing sarcoma
# 383                               Sarcoma other
# Name: cancerType, Length: 195, dtype: object
# probe identification for: Sarcoma other, 1 of 7 cancer types
# running analysis
# ['Sarcoma other' 'otherCancerType']
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
# Shape of data internal to the differential analysis (196, 4378)
# Shape of data internal to the differential analysis (195, 4045)
# Shape of data internal to the differential analysis (195, 3911)
# 1311    Bone tumour, Sarcoma
# 819            Sarcoma other
# 282            Sarcoma other
# 1357    Bone tumour, Sarcoma
# 90             Sarcoma other
#                 ...
# 478     Bone tumour, Sarcoma
# 101         Rhabdomyosarcoma
# 749            Sarcoma other
# 424         Rhabdomyosarcoma
# 383            Sarcoma other
# Name: cancerType, Length: 195, dtype: object
# probe identification for: Bone tumour, Sarcoma, 1 of 7 cancer types
# running analysis
# ['Bone tumour, Sarcoma' 'otherCancerType']
# 1311    Bone tumour, Sarcoma
# 313            Ewing sarcoma
# 1357    Bone tumour, Sarcoma
# 90             Sarcoma other
# 1075    Bone tumour, Sarcoma
#                 ...
# 749            Sarcoma other
# 265            Sarcoma other
# 424         Rhabdomyosarcoma
# 1067           Ewing sarcoma
# 1332           Ewing sarcoma
# Name: cancerType, Length: 196, dtype: object
# probe identification for: Bone tumour, Sarcoma, 1 of 7 cancer types
# running analysis
# ['Bone tumour, Sarcoma' 'otherCancerType']
# 819                               Sarcoma other
# 282                               Sarcoma other
# 313                               Ewing sarcoma
# 256     Peripheral nerve sheath tumour, Sarcoma
# 1075                       Bone tumour, Sarcoma
#                          ...
# 101                            Rhabdomyosarcoma
# 265                               Sarcoma other
# 1067                              Ewing sarcoma
# 1332                              Ewing sarcoma
# 383                               Sarcoma other
# Name: cancerType, Length: 195, dtype: object
# probe identification for: Sarcoma other, 1 of 7 cancer types
# running analysis
# ['Sarcoma other' 'otherCancerType']
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# ERROR:root:Error training model for Sarcoma: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# INFO:root:Training model for node: Vascular/lymphatic anomalies
# Vascular/lymphatic anomalies (13, 4855) (13, 2)
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# /data/projects/classifiers/methylation/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# 885           otherCancerType
# 638               Haemangioma
# 413               Haemangioma
# 540     Haemangioendothelioma
# 1107    Haemangioendothelioma
# 450              Malformation
# Name: cancerType, dtype: object
# probe identification for: otherCancerType, 1 of 4 cancer types
# running analysis
# ['otherCancerType']
# 885           otherCancerType
# 638               Haemangioma
# 420     Haemangioendothelioma
# 1156          otherCancerType
# 540     Haemangioendothelioma
# 857               Haemangioma
# 806              Malformation
# Name: cancerType, dtype: object
# probe identification for: otherCancerType, 1 of 4 cancer types
# running analysis
# ['otherCancerType']
# 885           otherCancerType
# 638               Haemangioma
# 420     Haemangioendothelioma
# 1156          otherCancerType
# 540     Haemangioendothelioma
# 857               Haemangioma
# 806              Malformation
# Name: cancerType, dtype: object
# probe identification for: otherCancerType, 1 of 4 cancer types
# running analysis
# ['otherCancerType']
# 885           otherCancerType
# 638               Haemangioma
# 413               Haemangioma
# 540     Haemangioendothelioma
# 1107    Haemangioendothelioma
# 450              Malformation
# Name: cancerType, dtype: object
# probe identification for: otherCancerType, 1 of 4 cancer types
# running analysis
# ['otherCancerType']
# 420     Haemangioendothelioma
# 413               Haemangioma
# 1156          otherCancerType
# 857               Haemangioma
# 1107    Haemangioendothelioma
# 450              Malformation
# 806              Malformation
# Name: cancerType, dtype: object
# probe identification for: Haemangioendothelioma, 1 of 4 cancer types
# running analysis
# ['Haemangioendothelioma' 'otherCancerType']
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# 885           otherCancerType
# 638               Haemangioma
# 413               Haemangioma
# 540     Haemangioendothelioma
# 1107    Haemangioendothelioma
# 450              Malformation
# Name: cancerType, dtype: object
# probe identification for: otherCancerType, 1 of 4 cancer types
# running analysis
# ['otherCancerType']
# Shape of data internal to the differential analysis (6, 4853)
# Shape of data internal to the differential analysis (7, 4853)
# INFO:rpy2.situation:R home found: /usr/lib/R
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
# 420     Haemangioendothelioma
# 413               Haemangioma
# 1156          otherCancerType
# 857               Haemangioma
# 1107    Haemangioendothelioma
# 450              Malformation
# 806              Malformation
# Name: cancerType, dtype: object
# probe identification for: Haemangioendothelioma, 1 of 4 cancer types
# running analysis
# ['Haemangioendothelioma' 'otherCancerType']
# Shape of data internal to the differential analysis (7, 4853)
# 885           otherCancerType
# 638               Haemangioma
# 420     Haemangioendothelioma
# 1156          otherCancerType
# 540     Haemangioendothelioma
# 857               Haemangioma
# 806              Malformation
# Name: cancerType, dtype: object
# probe identification for: otherCancerType, 1 of 4 cancer types
# running analysis
# ['otherCancerType']
# 885           otherCancerType
# 638               Haemangioma
# 413               Haemangioma
# 540     Haemangioendothelioma
# 1107    Haemangioendothelioma
# 450              Malformation
# Name: cancerType, dtype: object
# probe identification for: otherCancerType, 1 of 4 cancer types
# running analysis
# ['otherCancerType']
# ERROR:root:Error training model for Vascular/lymphatic anomalies: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# INFO:root:Training model for node: Overgrowth syndrome
# ERROR:root:Error training model for Overgrowth syndrome: cannot unpack non-iterable NoneType object
# INFO:root:Training model for node: Neuroblastoma
# ERROR:root:Error training model for Neuroblastoma: cannot unpack non-iterable NoneType object
# INFO:root:Training model for node: Haematological malignancy
# Overgrowth syndrome (1, 4855) (1, 2)
# Skipping, Overgrowth syndrome has fewer than 10 samples
# Neuroblastoma (103, 4855) (103, 2)
# Skipping, there is only one subgroup of Neuroblastoma
# Haematological malignancy (234, 4855) (234, 2)
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# /data/projects/classifiers/methylation/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# 908         Leukaemia
# 975          Lymphoma
# 1536    Histiocytosis
# 996         Leukaemia
# 1353         Lymphoma
#             ...
# 360         Leukaemia
# 641         Leukaemia
# 58           Lymphoma
# 542         Leukaemia
# 592         Leukaemia
# Name: cancerType, Length: 125, dtype: object
# probe identification for: Leukaemia, 1 of 5 cancer types
# running analysis
# ['Leukaemia' 'otherCancerType']
# 745         Leukaemia
# 943         Leukaemia
# 1353         Lymphoma
# 658         Leukaemia
# 568          Lymphoma
#             ...
# 360         Leukaemia
# 58           Lymphoma
# 542         Leukaemia
# 1084    Histiocytosis
# 592         Leukaemia
# Name: cancerType, Length: 124, dtype: object
# probe identification for: Leukaemia, 1 of 4 cancer types
# running analysis
# ['Leukaemia' 'otherCancerType']
# 745         Leukaemia
# 943         Leukaemia
# 908         Leukaemia
# 975          Lymphoma
# 1536    Histiocytosis
#             ...
# 1715        Leukaemia
# 109         Leukaemia
# 1149         Lymphoma
# 641         Leukaemia
# 1084    Histiocytosis
# Name: cancerType, Length: 125, dtype: object
# probe identification for: Leukaemia, 1 of 5 cancer types
# running analysis
# ['Leukaemia' 'otherCancerType']
# 908         Leukaemia
# 975          Lymphoma
# 1536    Histiocytosis
# 996         Leukaemia
# 1353         Lymphoma
#             ...
# 360         Leukaemia
# 641         Leukaemia
# 58           Lymphoma
# 542         Leukaemia
# 592         Leukaemia
# Name: cancerType, Length: 125, dtype: object
# probe identification for: Leukaemia, 1 of 5 cancer types
# running analysis
# ['Leukaemia' 'otherCancerType']
# 745         Leukaemia
# 943         Leukaemia
# 908         Leukaemia
# 975          Lymphoma
# 1536    Histiocytosis
#             ...
# 1715        Leukaemia
# 109         Leukaemia
# 1149         Lymphoma
# 641         Leukaemia
# 1084    Histiocytosis
# Name: cancerType, Length: 125, dtype: object
# probe identification for: Leukaemia, 1 of 5 cancer types
# running analysis
# ['Leukaemia' 'otherCancerType']
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# Shape of data internal to the differential analysis (125, 4505)
# 908         Leukaemia
# 975          Lymphoma
# 1536    Histiocytosis
# 996         Leukaemia
# 1353         Lymphoma
#             ...
# 360         Leukaemia
# 641         Leukaemia
# 58           Lymphoma
# 542         Leukaemia
# 592         Leukaemia
# Name: cancerType, Length: 125, dtype: object
# probe identification for: Leukaemia, 1 of 5 cancer types
# running analysis
# ['Leukaemia' 'otherCancerType']
# Shape of data internal to the differential analysis (124, 4154)
# 908         Leukaemia
# 975          Lymphoma
# 1536    Histiocytosis
# 996         Leukaemia
# 1353         Lymphoma
#             ...
# 360         Leukaemia
# 641         Leukaemia
# 58           Lymphoma
# 542         Leukaemia
# 592         Leukaemia
# Name: cancerType, Length: 125, dtype: object
# probe identification for: Leukaemia, 1 of 5 cancer types
# running analysis
# ['Leukaemia' 'otherCancerType']
# Shape of data internal to the differential analysis (125, 3990)
# 745         Leukaemia
# 943         Leukaemia
# 1353         Lymphoma
# 658         Leukaemia
# 568          Lymphoma
#             ...
# 360         Leukaemia
# 58           Lymphoma
# 542         Leukaemia
# 1084    Histiocytosis
# 592         Leukaemia
# Name: cancerType, Length: 124, dtype: object
# probe identification for: Leukaemia, 1 of 4 cancer types
# running analysis
# ['Leukaemia' 'otherCancerType']
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# ERROR:root:Error training model for Haematological malignancy: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# INFO:root:Training model for node: Central nervous system
# Central nervous system (494, 4855) (494, 2)
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# /data/projects/classifiers/methylation/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.
# 1271      Paediatric-type diffuse glioma
# 210                 CNS embryonal tumour
# 665       Paediatric-type diffuse glioma
# 1043    Glioneuronal and neuronal tumour
# 1390      Paediatric-type diffuse glioma
#                       ...
# 1775      Paediatric-type diffuse glioma
# 253       Paediatric-type diffuse glioma
# 376       Paediatric-type diffuse glioma
# 990       Paediatric-type diffuse glioma
# 362       Paediatric-type diffuse glioma
# Name: cancerType, Length: 263, dtype: object
# probe identification for: Paediatric-type diffuse glioma, 1 of 14 cancer types
# running analysis
# ['Paediatric-type diffuse glioma' 'otherCancerType']
# 1271      Paediatric-type diffuse glioma
# 210                 CNS embryonal tumour
# 665       Paediatric-type diffuse glioma
# 1043    Glioneuronal and neuronal tumour
# 1390      Paediatric-type diffuse glioma
#                       ...
# 1775      Paediatric-type diffuse glioma
# 253       Paediatric-type diffuse glioma
# 376       Paediatric-type diffuse glioma
# 990       Paediatric-type diffuse glioma
# 362       Paediatric-type diffuse glioma
# Name: cancerType, Length: 263, dtype: object
# probe identification for: Paediatric-type diffuse glioma, 1 of 14 cancer types
# running analysis
# ['Paediatric-type diffuse glioma' 'otherCancerType']
# 1002      Paediatric-type diffuse glioma
# 1390      Paediatric-type diffuse glioma
# 924     Glioneuronal and neuronal tumour
# 1384    Glioneuronal and neuronal tumour
# 91       Circumscribed astrocytic glioma
#                       ...
# 64        Paediatric-type diffuse glioma
# 606                           Meningioma
# 376       Paediatric-type diffuse glioma
# 781      Circumscribed astrocytic glioma
# 1260               Germ cell tumour, CNS
# Name: cancerType, Length: 264, dtype: object
# probe identification for: Paediatric-type diffuse glioma, 1 of 14 cancer types
# running analysis
# ['Paediatric-type diffuse glioma' 'otherCancerType']
# 1271      Paediatric-type diffuse glioma
# 210                 CNS embryonal tumour
# 1002      Paediatric-type diffuse glioma
# 665       Paediatric-type diffuse glioma
# 1043    Glioneuronal and neuronal tumour
#                       ...
# 253       Paediatric-type diffuse glioma
# 781      Circumscribed astrocytic glioma
# 990       Paediatric-type diffuse glioma
# 1260               Germ cell tumour, CNS
# 362       Paediatric-type diffuse glioma
# Name: cancerType, Length: 263, dtype: object
# probe identification for: Paediatric-type diffuse glioma, 1 of 14 cancer types
# running analysis
# ['Paediatric-type diffuse glioma' 'otherCancerType']
# 1002      Paediatric-type diffuse glioma
# 1390      Paediatric-type diffuse glioma
# 924     Glioneuronal and neuronal tumour
# 1384    Glioneuronal and neuronal tumour
# 91       Circumscribed astrocytic glioma
#                       ...
# 64        Paediatric-type diffuse glioma
# 606                           Meningioma
# 376       Paediatric-type diffuse glioma
# 781      Circumscribed astrocytic glioma
# 1260               Germ cell tumour, CNS
# Name: cancerType, Length: 264, dtype: object
# probe identification for: Paediatric-type diffuse glioma, 1 of 14 cancer types
# running analysis
# ['Paediatric-type diffuse glioma' 'otherCancerType']
# 1271      Paediatric-type diffuse glioma
# 210                 CNS embryonal tumour
# 665       Paediatric-type diffuse glioma
# 1043    Glioneuronal and neuronal tumour
# 1390      Paediatric-type diffuse glioma
#                       ...
# 1775      Paediatric-type diffuse glioma
# 253       Paediatric-type diffuse glioma
# 376       Paediatric-type diffuse glioma
# 990       Paediatric-type diffuse glioma
# 362       Paediatric-type diffuse glioma
# Name: cancerType, Length: 263, dtype: object
# probe identification for: Paediatric-type diffuse glioma, 1 of 14 cancer types
# running analysis
# ['Paediatric-type diffuse glioma' 'otherCancerType']
# Shape of data internal to the differential analysis (263, 4378)
# Shape of data internal to the differential analysis (263, 4378)
# Shape of data internal to the differential analysis (263, 4378)
# Shape of data internal to the differential analysis (264, 4378)
# 1271      Paediatric-type diffuse glioma
# 210                 CNS embryonal tumour
# 665       Paediatric-type diffuse glioma
# 1043    Glioneuronal and neuronal tumour
# 1390      Paediatric-type diffuse glioma
#                       ...
# 1775      Paediatric-type diffuse glioma
# 253       Paediatric-type diffuse glioma
# 376       Paediatric-type diffuse glioma
# 990       Paediatric-type diffuse glioma
# 362       Paediatric-type diffuse glioma
# Name: cancerType, Length: 263, dtype: object
# probe identification for: Paediatric-type diffuse glioma, 1 of 14 cancer types
# running analysis
# ['Paediatric-type diffuse glioma' 'otherCancerType']
# Shape of data internal to the differential analysis (264, 4378)
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# INFO:rpy2.situation:R home found: /usr/lib/R
# INFO:rpy2.situation:R home found: /usr/lib/R
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(filename, "r", encoding = encoding) :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'differentialMethylation.R': No such file or directory
#
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.situation:R library path: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.situation:LD_LIBRARY_PATH: /usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# ERROR:root:Error training model for Central nervous system: Error in file(filename, "r", encoding = encoding) :
#   cannot open the connection
# 1002      Paediatric-type diffuse glioma
# 1390      Paediatric-type diffuse glioma
# 924     Glioneuronal and neuronal tumour
# 1384    Glioneuronal and neuronal tumour
# 91       Circumscribed astrocytic glioma
#                       ...
# 64        Paediatric-type diffuse glioma
# 606                           Meningioma
# 376       Paediatric-type diffuse glioma
# 781      Circumscribed astrocytic glioma
# 1260               Germ cell tumour, CNS
# Name: cancerType, Length: 264, dtype: object
# probe identification for: Paediatric-type diffuse glioma, 1 of 14 cancer types
# running analysis
# ['Paediatric-type diffuse glioma' 'otherCancerType']
# 1271      Paediatric-type diffuse glioma
# 210                 CNS embryonal tumour
# 1002      Paediatric-type diffuse glioma
# 665       Paediatric-type diffuse glioma
# 1043    Glioneuronal and neuronal tumour
#                       ...
# 253       Paediatric-type diffuse glioma
# 781      Circumscribed astrocytic glioma
# 990       Paediatric-type diffuse glioma
# 1260               Germ cell tumour, CNS
# 362       Paediatric-type diffuse glioma
# Name: cancerType, Length: 263, dtype: object
# probe identification for: Paediatric-type diffuse glioma, 1 of 14 cancer types
# running analysis
# ['Paediatric-type diffuse glioma' 'otherCancerType']
# {'Solid tumour': {'error': 'Error in file(filename, "r", encoding = encoding) : \n  cannot open the connection\n'},
#  'Sarcoma': {'error': 'Error in file(filename, "r", encoding = encoding) : \n  cannot open the connection\n'},
#  'Vascular/lymphatic anomalies': {'error': 'Error in file(filename, "r", encoding = encoding) : \n  cannot open the connection\n'},
#  'Overgrowth syndrome': {'error': 'cannot unpack non-iterable NoneType object'},
#  'Neuroblastoma': {'error': 'cannot unpack non-iterable NoneType object'},
#  'Haematological malignancy': {'error': 'Error in file(filename, "r", encoding = encoding) : \n  cannot open the connection\n'},
#  'Central nervous system': {'error': 'Error in file(filename, "r", encoding = encoding) : \n  cannot open the connection\n'}}

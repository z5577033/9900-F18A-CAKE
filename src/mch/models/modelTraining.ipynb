# %%
from pathlib import Path
import rpy2.robjects as ro
ro.r('options(rpy2_quiet=TRUE)')
print(ro.r('R.version.string'))  # rpy status check
ro.r('library(limma); library(arrow)')  
ro.r['source'](str(Path('/app/src/mch/models/differentialMethylation.R')))
print(ro.r('exists("runDM")'))  # load R library check: TRUE
print(ro.r('Sys.getenv("R_HOME")'))
# Out:
# [1] "R version 4.3.3 (2024-02-29)"
#
# [1] TRUE
#
# [1] "/usr/lib/R"

# %%
from mch.models.training import BatchModelTrainer
from mch.config.modelTrainingParameters import resultsDirectory, parameter_grid

# %%
models = BatchModelTrainer()
stats = models.train_all_models(raise_on_error=True)
stats
# Out:
# 2025-10-19 12:31:29,390 INFO mch.training: Training model for node: Neuroblastoma
# Neuroblastoma origin data count: 390
# Neuroblastoma mvalue_df columns: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Neuroblastoma diseaseTree count: 119
# Neuroblastoma joint count: 25
# Neuroblastoma joint samples: ['23Y760LJ_T_2J0J64U5_M', '2GYT5RNM_T_1GR2RR9X_M', '1XKJVYPQ_T_9MUZXBUX_M', 'WKKCTLNZ_T_2DQ5W5GT_M', 'V20LWAKK_T_L76Z4QRZ_M']
# Neuroblastoma Data after filter: 25
# Neuroblastoma Data after design filter: 25
# Neuroblastoma 25 25
# 2025-10-19 12:31:36,713 INFO mch.training: Training model for node: Vascular/lymphatic anomalies
# Skipping, there is only one subgroup of Neuroblastoma
# Vascular/lymphatic anomalies origin data count: 390
# Vascular/lymphatic anomalies mvalue_df columns: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Vascular/lymphatic anomalies diseaseTree count: 1
# Vascular/lymphatic anomalies joint count: 0
# Vascular/lymphatic anomalies joint samples: []
# 2025-10-19 12:31:39,949 INFO mch.training: Training model for node: Haematological malignancy
# Vascular/lymphatic anomalies Data after filter: 0
# Vascular/lymphatic anomalies Data after design filter: 0
# Vascular/lymphatic anomalies 0 0
# Skipping, Vascular/lymphatic anomalies has fewer than 10 samples
# Haematological malignancy origin data count: 390
# Haematological malignancy mvalue_df columns: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Haematological malignancy diseaseTree count: 496
# Haematological malignancy joint count: 108
# Haematological malignancy joint samples: ['FM97AMTG_T_20N8ZPKL_M', '1UCKPR6W_T_FTYQGBUB_M', '1XQYA97S_T_1J6TM9XW_M', '2EQDQ4XT_T_LAEHLQTT_M', 'EMPPQ04B_T_N8XDL910_M']
# Haematological malignancy Data after filter: 108
# Haematological malignancy Data after design filter: 108
# Haematological malignancy 108 108
# design type： <class 'polars.dataframe.frame.DataFrame'>
# 2025-10-19 12:32:13,168 WARNING mch.training: parameter_grid is None/empty, fit pipeline without grid search
# probe identification for: Leukaemia, 1 of 4 cancer types
# Running analysis
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

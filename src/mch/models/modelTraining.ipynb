# %%
from mch.models.training import BatchModelTrainer
from mch.config.modelTrainingParameters import resultsDirectory, parameter_grid

# %%
models = BatchModelTrainer()
models.train_all_models()
# Out:
# Neuroblastoma 原始数据量: 390
# Neuroblastoma mvalue_df 列名: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Neuroblastoma diseaseSamples 数量: 119
# Neuroblastoma diseaseSamples 示例: ['2J0D2U4J_T_XJAFP6HU_M', '1Y5U23JX_T_2BJWTAD0_M', 'LLV8BE5A_T_49HWBVUM_M', '28UATA2X_T_2846CY4M_M', '2TY83VAJ_T_26ZX1KHP_M']
# Neuroblastoma diseaseSamples 类型: <class 'str'>
# Neuroblastoma biosample_id 示例: ['2U93HQPK_T_KF9ZUGBB_M', 'PCVR0FYE_T_GAP27080_M', '2BEJ5TYN_T_27U4XZSE_M', 'ZA7FATL3_T_13GA5RMS_M', 'B33U0Y4A_T_1ZBDYQU7_M']
# Neuroblastoma biosample_id 类型: <class 'str'>
# Neuroblastoma 交集数量: 0
# Neuroblastoma 交集示例: []
# Neuroblastoma 筛选后数据量: 0
# Neuroblastoma 筛选后 design 数据量: 0
# Neuroblastoma 0 0
# Skipping, Neuroblastoma has fewer than 10 samples
# Vascular/lymphatic anomalies 原始数据量: 390
# Vascular/lymphatic anomalies mvalue_df 列名: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Vascular/lymphatic anomalies diseaseSamples 数量: 1
# Vascular/lymphatic anomalies diseaseSamples 示例: ['2FRQ6RW6_T_12QK30T9_M']
# Vascular/lymphatic anomalies diseaseSamples 类型: <class 'str'>
# Vascular/lymphatic anomalies biosample_id 示例: ['2U93HQPK_T_KF9ZUGBB_M', 'PCVR0FYE_T_GAP27080_M', '2BEJ5TYN_T_27U4XZSE_M', 'ZA7FATL3_T_13GA5RMS_M', 'B33U0Y4A_T_1ZBDYQU7_M']
# Vascular/lymphatic anomalies biosample_id 类型: <class 'str'>
# Vascular/lymphatic anomalies 交集数量: 0
# Vascular/lymphatic anomalies 交集示例: []
# ERROR:root:Error training model for Haematological malignancy: Histiocytosis
# ERROR:root:Error training model for Sarcoma: Liver tumour, Sarcoma
# ERROR:root:Error training model for Solid tumour: Adrenal cortical tumour
# ERROR:root:Error training model for Central nervous system: Sellar tumour
# Vascular/lymphatic anomalies 筛选后数据量: 0
# Vascular/lymphatic anomalies 筛选后 design 数据量: 0
# Vascular/lymphatic anomalies 0 0
# Skipping, Vascular/lymphatic anomalies has fewer than 10 samples
# Haematological malignancy 原始数据量: 390
# Haematological malignancy mvalue_df 列名: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Haematological malignancy diseaseSamples 数量: 496
# Sarcoma 原始数据量: 390
# Sarcoma mvalue_df 列名: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Sarcoma diseaseSamples 数量: 402
# Solid tumour 原始数据量: 390
# Solid tumour mvalue_df 列名: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Solid tumour diseaseSamples 数量: 215
# Central nervous system 原始数据量: 390
# Central nervous system mvalue_df 列名: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Central nervous system diseaseSamples 数量: 633
# Overgrowth syndrome 原始数据量: 390
# Overgrowth syndrome mvalue_df 列名: ['biosample_id', 'cg00000029', 'cg00000109', 'cg00000155', 'cg00000158']
# Overgrowth syndrome diseaseSamples 数量: 2
# Overgrowth syndrome diseaseSamples 示例: ['3Q49KAM9_T_25Q0DGWD_M', '16URXX0C_T_1S005XB2_M']
# Overgrowth syndrome diseaseSamples 类型: <class 'str'>
# Overgrowth syndrome biosample_id 示例: ['2U93HQPK_T_KF9ZUGBB_M', 'PCVR0FYE_T_GAP27080_M', '2BEJ5TYN_T_27U4XZSE_M', 'ZA7FATL3_T_13GA5RMS_M', 'B33U0Y4A_T_1ZBDYQU7_M']
# Overgrowth syndrome biosample_id 类型: <class 'str'>
# Overgrowth syndrome 交集数量: 0
# Overgrowth syndrome 交集示例: []
# Overgrowth syndrome 筛选后数据量: 0
# Overgrowth syndrome 筛选后 design 数据量: 0
# Overgrowth syndrome 0 0
# Skipping, Overgrowth syndrome has fewer than 10 samples
# {'Haematological malignancy': {'error': 'Histiocytosis'},
#  'Sarcoma': {'error': 'Liver tumour, Sarcoma'},
#  'Solid tumour': {'error': 'Adrenal cortical tumour'},
#  'Central nervous system': {'error': 'Sellar tumour'}}
